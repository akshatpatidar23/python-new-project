# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns 


df = pd.read_csv('your_file.csv')


df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import matplotlib.pyplot as plt
#       2 import seaborn as sns
#       3
#       4
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
pip install pandas numpy matplotlib seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.3 MB 1.4 MB/s eta 0:00:07
#    --- ------------------------------------ 0.8/9.3 MB 1.4 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.3/9.3 MB 1.5 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.3/9.3 MB 1.5 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.3/9.3 MB 1.5 MB/s eta 0:00:06
#    ------ --------------------------------- 1.6/9.3 MB 1.1 MB/s eta 0:00:07
#    ------ --------------------------------- 1.6/9.3 MB 1.1 MB/s eta 0:00:07
#    ------ --------------------------------- 1.6/9.3 MB 1.1 MB/s eta 0:00:07
#    ------- -------------------------------- 1.8/9.3 MB 897.3 kB/s eta 0:00:09
#    ------- -------------------------------- 1.8/9.3 MB 897.3 kB/s eta 0:00:09
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns  # Highly recommended for making heatmaps easier

# Load the CSV file (Replace 'your_file.csv' with your actual file path or URL)
df = pd.read_csv(r"C:\Users\aksha\Downloads\synthetic_dataset for feature engg.csv")

# Display the first 5 rows to understand the structure of your data
df.head()
# Out:
#   Category   Price    Rating         Stock  Discount
# 0      NaN  5548.0  1.870322           NaN       0.0
# 1      NaN  3045.0  4.757798           NaN      38.0
# 2      NaN  4004.0       NaN      In Stock       0.0
# 3      NaN  4808.0  1.492085           NaN      33.0
# 4      NaN  1817.0       NaN  Out of Stock      23.0
